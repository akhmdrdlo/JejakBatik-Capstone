# %%
import zipfile
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import os
from collections import defaultdict
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from ipywidgets import FileUpload, Output
from IPython.display import display

# paths and parameters
TRAIN_DIR = "DATASET/TRAIN/"
TEST_DIR = "DATASET/TEST/"
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
BATCH_SIZE = 16
EPOCHS_INITIAL = 45
EPOCHS_FINE_TUNE = 20
MODEL_DIR = "./model_uray"
CHECKPOINT_FILE = "model_checkpoint_best_final_3.keras"
CHECKPOINT_PATH = os.path.join(MODEL_DIR, CHECKPOINT_FILE)
LEARNING_RATE_FINE_TUNE = 1e-5

# Create model directory if not exists
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    brightness_range=[0.9, 1.1],
    horizontal_flip=True,
    fill_mode="nearest",
)

test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training",
    shuffle="True"
)

validation_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation",
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
)
# Out:
# Found 688 images belonging to 26 classes.
# Found 159 images belonging to 26 classes.
# Found 208 images belonging to 26 classes.

# %%
from tensorflow.keras.regularizers import l2
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(512, activation="relu", kernel_regularizer=l2(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
output_layer = Dense(
    train_generator.num_classes,
    activation="softmax",
    kernel_regularizer=l2(1e-4),
)(x)

model = Model(inputs=base_model.input, outputs=output_layer)

# Freeze some of the deeper base model layers
for layer in base_model.layers[:120]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

# Load checkpoint if exists
if os.path.exists(CHECKPOINT_PATH):
    print("Checkpoint found. Loading model...")
    model = tf.keras.models.load_model(CHECKPOINT_PATH)
else:
    print("No checkpoint found. Training model from scratch...")
# Out:
# No checkpoint found. Training model from scratch...

# %%
callbacks = [
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=8),
    ModelCheckpoint(CHECKPOINT_PATH, monitor="val_accuracy", save_best_only=True, save_weights_only=False, verbose=1),
]

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS_INITIAL,
    validation_data=validation_generator,
    callbacks=callbacks,
)

# Fine-tuning
for layer in base_model.layers:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE_FINE_TUNE, weight_decay=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

history_fine_tune = model.fit(
    train_generator,
    epochs=EPOCHS_FINE_TUNE,
    validation_data=validation_generator,
    callbacks=callbacks,
)
# Out:
# Epoch 1/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.0675 - loss: 4.1210
# Epoch 1: val_accuracy improved from -inf to 0.22013, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 17s 174ms/step - accuracy: 0.0688 - loss: 4.1114 - val_accuracy: 0.2201 - val_loss: 2.8863 - learning_rate: 1.0000e-04
# Epoch 2/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3585 - loss: 2.4869
# Epoch 2: val_accuracy improved from 0.22013 to 0.29560, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3590 - loss: 2.4840 - val_accuracy: 0.2956 - val_loss: 2.5083 - learning_rate: 1.0000e-04
# Epoch 3/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5387 - loss: 1.6963
# Epoch 3: val_accuracy improved from 0.29560 to 0.35849, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.5387 - loss: 1.6959 - val_accuracy: 0.3585 - val_loss: 2.3764 - learning_rate: 1.0000e-04
# Epoch 4/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6508 - loss: 1.3382
# Epoch 4: val_accuracy improved from 0.35849 to 0.42767, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.6508 - loss: 1.3367 - val_accuracy: 0.4277 - val_loss: 2.1230 - learning_rate: 1.0000e-04
# Epoch 5/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6811 - loss: 1.0764
# Epoch 5: val_accuracy improved from 0.42767 to 0.50314, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.6819 - loss: 1.0754 - val_accuracy: 0.5031 - val_loss: 2.0402 - learning_rate: 1.0000e-04
# Epoch 6/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7590 - loss: 0.9271
# Epoch 6: val_accuracy improved from 0.50314 to 0.55346, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.7593 - loss: 0.9264 - val_accuracy: 0.5535 - val_loss: 1.8982 - learning_rate: 1.0000e-04
# Epoch 7/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8334 - loss: 0.7254
# Epoch 7: val_accuracy did not improve from 0.55346
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8334 - loss: 0.7250 - val_accuracy: 0.4843 - val_loss: 1.8762 - learning_rate: 1.0000e-04
# Epoch 8/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8302 - loss: 0.6518
# Epoch 8: val_accuracy did not improve from 0.55346
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8299 - loss: 0.6526 - val_accuracy: 0.5409 - val_loss: 1.7471 - learning_rate: 1.0000e-04
# Epoch 9/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8602 - loss: 0.5522
# Epoch 9: val_accuracy improved from 0.55346 to 0.56604, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.8604 - loss: 0.5525 - val_accuracy: 0.5660 - val_loss: 1.7221 - learning_rate: 1.0000e-04
# Epoch 10/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8646 - loss: 0.4988
# Epoch 10: val_accuracy did not improve from 0.56604
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.8649 - loss: 0.4985 - val_accuracy: 0.5535 - val_loss: 1.6575 - learning_rate: 1.0000e-04
# Epoch 11/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8874 - loss: 0.4846
# Epoch 11: val_accuracy improved from 0.56604 to 0.60377, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8873 - loss: 0.4845 - val_accuracy: 0.6038 - val_loss: 1.6961 - learning_rate: 1.0000e-04
# Epoch 12/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9120 - loss: 0.3961
# Epoch 12: val_accuracy did not improve from 0.60377
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9119 - loss: 0.3958 - val_accuracy: 0.5849 - val_loss: 1.6384 - learning_rate: 1.0000e-04
# Epoch 13/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9335 - loss: 0.3609
# Epoch 13: val_accuracy improved from 0.60377 to 0.62893, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9334 - loss: 0.3603 - val_accuracy: 0.6289 - val_loss: 1.5655 - learning_rate: 1.0000e-04
# Epoch 14/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9499 - loss: 0.2922
# Epoch 14: val_accuracy improved from 0.62893 to 0.63522, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9495 - loss: 0.2927 - val_accuracy: 0.6352 - val_loss: 1.4241 - learning_rate: 1.0000e-04
# Epoch 15/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9282 - loss: 0.3395
# Epoch 15: val_accuracy improved from 0.63522 to 0.67296, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9284 - loss: 0.3389 - val_accuracy: 0.6730 - val_loss: 1.4815 - learning_rate: 1.0000e-04
# Epoch 16/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9643 - loss: 0.2485
# Epoch 16: val_accuracy did not improve from 0.67296
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9642 - loss: 0.2488 - val_accuracy: 0.6415 - val_loss: 1.4381 - learning_rate: 1.0000e-04
# Epoch 17/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9579 - loss: 0.2285
# Epoch 17: val_accuracy improved from 0.67296 to 0.69811, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.9575 - loss: 0.2293 - val_accuracy: 0.6981 - val_loss: 1.3443 - learning_rate: 1.0000e-04
# Epoch 18/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9644 - loss: 0.2234
# Epoch 18: val_accuracy did not improve from 0.69811
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9644 - loss: 0.2233 - val_accuracy: 0.6541 - val_loss: 1.4701 - learning_rate: 1.0000e-04
# Epoch 19/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9559 - loss: 0.2562
# Epoch 19: val_accuracy did not improve from 0.69811
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9561 - loss: 0.2556 - val_accuracy: 0.6918 - val_loss: 1.3821 - learning_rate: 1.0000e-04
# Epoch 20/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9570 - loss: 0.2440
# Epoch 20: val_accuracy improved from 0.69811 to 0.72327, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9571 - loss: 0.2438 - val_accuracy: 0.7233 - val_loss: 1.3528 - learning_rate: 1.0000e-04
# Epoch 21/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9807 - loss: 0.1803
# Epoch 21: val_accuracy did not improve from 0.72327
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9806 - loss: 0.1804 - val_accuracy: 0.7233 - val_loss: 1.3755 - learning_rate: 1.0000e-04
# Epoch 22/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9825 - loss: 0.1642
# Epoch 22: val_accuracy did not improve from 0.72327
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9823 - loss: 0.1644 - val_accuracy: 0.7107 - val_loss: 1.4134 - learning_rate: 1.0000e-04
# Epoch 23/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9852 - loss: 0.1721
# Epoch 23: val_accuracy improved from 0.72327 to 0.72956, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9850 - loss: 0.1725 - val_accuracy: 0.7296 - val_loss: 1.3424 - learning_rate: 1.0000e-04
# Epoch 24/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9844 - loss: 0.1566
# Epoch 24: val_accuracy improved from 0.72956 to 0.74843, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9842 - loss: 0.1568 - val_accuracy: 0.7484 - val_loss: 1.4017 - learning_rate: 1.0000e-04
# Epoch 25/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9925 - loss: 0.1481
# Epoch 25: val_accuracy did not improve from 0.74843
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9925 - loss: 0.1481 - val_accuracy: 0.7296 - val_loss: 1.3560 - learning_rate: 1.0000e-04
# Epoch 26/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9767 - loss: 0.1553
# Epoch 26: val_accuracy did not improve from 0.74843
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9767 - loss: 0.1555 - val_accuracy: 0.7233 - val_loss: 1.3971 - learning_rate: 1.0000e-04
# Epoch 27/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9771 - loss: 0.1610
# Epoch 27: val_accuracy did not improve from 0.74843
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9771 - loss: 0.1610 - val_accuracy: 0.7296 - val_loss: 1.3498 - learning_rate: 1.0000e-04
# Epoch 28/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9889 - loss: 0.1396
# Epoch 28: val_accuracy did not improve from 0.74843
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9889 - loss: 0.1395 - val_accuracy: 0.7296 - val_loss: 1.1919 - learning_rate: 1.0000e-04
# Epoch 29/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9791 - loss: 0.1669
# Epoch 29: val_accuracy improved from 0.74843 to 0.76101, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.9793 - loss: 0.1664 - val_accuracy: 0.7610 - val_loss: 1.2349 - learning_rate: 1.0000e-04
# Epoch 30/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9885 - loss: 0.1362
# Epoch 30: val_accuracy improved from 0.76101 to 0.78616, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9885 - loss: 0.1362 - val_accuracy: 0.7862 - val_loss: 1.1608 - learning_rate: 1.0000e-04
# Epoch 31/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9817 - loss: 0.1415
# Epoch 31: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.9818 - loss: 0.1416 - val_accuracy: 0.7107 - val_loss: 1.4586 - learning_rate: 1.0000e-04
# Epoch 32/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9775 - loss: 0.1604
# Epoch 32: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9774 - loss: 0.1605 - val_accuracy: 0.7358 - val_loss: 1.4266 - learning_rate: 1.0000e-04
# Epoch 33/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9752 - loss: 0.1594
# Epoch 33: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9753 - loss: 0.1594 - val_accuracy: 0.7233 - val_loss: 1.3753 - learning_rate: 1.0000e-04
# Epoch 34/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9849 - loss: 0.1353
# Epoch 34: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.9848 - loss: 0.1355 - val_accuracy: 0.7233 - val_loss: 1.4116 - learning_rate: 1.0000e-04
# Epoch 35/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9916 - loss: 0.1162
# Epoch 35: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9916 - loss: 0.1162 - val_accuracy: 0.7170 - val_loss: 1.3010 - learning_rate: 1.0000e-04
# Epoch 36/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9841 - loss: 0.1308
# Epoch 36: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9841 - loss: 0.1308 - val_accuracy: 0.7296 - val_loss: 1.3787 - learning_rate: 1.0000e-04
# Epoch 37/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9860 - loss: 0.1360
# Epoch 37: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9860 - loss: 0.1359 - val_accuracy: 0.7673 - val_loss: 1.2656 - learning_rate: 1.0000e-04
# Epoch 38/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9882 - loss: 0.1185
# Epoch 38: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9883 - loss: 0.1184 - val_accuracy: 0.7673 - val_loss: 1.2442 - learning_rate: 1.0000e-04
# Epoch 39/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9916 - loss: 0.1203
# Epoch 39: val_accuracy did not improve from 0.78616
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9916 - loss: 0.1204 - val_accuracy: 0.7673 - val_loss: 1.1556 - learning_rate: 5.0000e-05
# Epoch 40/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9979 - loss: 0.1075
# Epoch 40: val_accuracy improved from 0.78616 to 0.79245, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9978 - loss: 0.1078 - val_accuracy: 0.7925 - val_loss: 1.1989 - learning_rate: 5.0000e-05
# Epoch 41/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9885 - loss: 0.1181
# Epoch 41: val_accuracy did not improve from 0.79245
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9886 - loss: 0.1181 - val_accuracy: 0.7925 - val_loss: 1.1244 - learning_rate: 5.0000e-05
# Epoch 42/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9853 - loss: 0.1376
# Epoch 42: val_accuracy did not improve from 0.79245
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.9853 - loss: 0.1375 - val_accuracy: 0.7799 - val_loss: 1.2400 - learning_rate: 5.0000e-05
# Epoch 43/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9913 - loss: 0.1199
# Epoch 43: val_accuracy did not improve from 0.79245
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9913 - loss: 0.1200 - val_accuracy: 0.7925 - val_loss: 1.1285 - learning_rate: 5.0000e-05
# Epoch 44/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9943 - loss: 0.1080
# Epoch 44: val_accuracy did not improve from 0.79245
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9943 - loss: 0.1080 - val_accuracy: 0.7610 - val_loss: 1.1678 - learning_rate: 5.0000e-05
# Epoch 45/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9945 - loss: 0.1112
# Epoch 45: val_accuracy did not improve from 0.79245
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9944 - loss: 0.1112 - val_accuracy: 0.7799 - val_loss: 1.1028 - learning_rate: 5.0000e-05
# Epoch 1/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8763 - loss: 0.4639
# Epoch 1: val_accuracy did not improve from 0.79245
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 43s 210ms/step - accuracy: 0.8766 - loss: 0.4634 - val_accuracy: 0.7673 - val_loss: 1.2272 - learning_rate: 1.0000e-05
# Epoch 2/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9008 - loss: 0.4009
# Epoch 2: val_accuracy did not improve from 0.79245
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9008 - loss: 0.4013 - val_accuracy: 0.7862 - val_loss: 1.1435 - learning_rate: 1.0000e-05
# Epoch 3/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8896 - loss: 0.4245
# Epoch 3: val_accuracy improved from 0.79245 to 0.79874, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.8901 - loss: 0.4238 - val_accuracy: 0.7987 - val_loss: 1.1789 - learning_rate: 1.0000e-05
# Epoch 4/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9154 - loss: 0.3707
# Epoch 4: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9155 - loss: 0.3700 - val_accuracy: 0.7987 - val_loss: 1.1112 - learning_rate: 1.0000e-05
# Epoch 5/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8930 - loss: 0.3952
# Epoch 5: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.8932 - loss: 0.3950 - val_accuracy: 0.7799 - val_loss: 1.1124 - learning_rate: 1.0000e-05
# Epoch 6/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9311 - loss: 0.3164
# Epoch 6: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9311 - loss: 0.3164 - val_accuracy: 0.7862 - val_loss: 1.0849 - learning_rate: 1.0000e-05
# Epoch 7/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9283 - loss: 0.3022
# Epoch 7: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9283 - loss: 0.3021 - val_accuracy: 0.7925 - val_loss: 0.9107 - learning_rate: 1.0000e-05
# Epoch 8/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9399 - loss: 0.3158
# Epoch 8: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9397 - loss: 0.3159 - val_accuracy: 0.7799 - val_loss: 1.0970 - learning_rate: 1.0000e-05
# Epoch 9/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9321 - loss: 0.2971
# Epoch 9: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9320 - loss: 0.2978 - val_accuracy: 0.7987 - val_loss: 1.1008 - learning_rate: 1.0000e-05
# Epoch 10/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9402 - loss: 0.2859
# Epoch 10: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9402 - loss: 0.2861 - val_accuracy: 0.7862 - val_loss: 1.0569 - learning_rate: 1.0000e-05
# Epoch 11/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9268 - loss: 0.3112
# Epoch 11: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9269 - loss: 0.3108 - val_accuracy: 0.7987 - val_loss: 1.1807 - learning_rate: 1.0000e-05
# Epoch 12/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9730 - loss: 0.2020
# Epoch 12: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9727 - loss: 0.2026 - val_accuracy: 0.7736 - val_loss: 1.0739 - learning_rate: 1.0000e-05
# Epoch 13/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9566 - loss: 0.2286
# Epoch 13: val_accuracy improved from 0.79874 to 0.81132, saving model to ./model_uray/model_checkpoint_best_final_3.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9566 - loss: 0.2289 - val_accuracy: 0.8113 - val_loss: 1.1171 - learning_rate: 1.0000e-05
# Epoch 14/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9594 - loss: 0.2156
# Epoch 14: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9594 - loss: 0.2158 - val_accuracy: 0.7862 - val_loss: 1.0718 - learning_rate: 1.0000e-05
# Epoch 15/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9636 - loss: 0.2111
# Epoch 15: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9637 - loss: 0.2107 - val_accuracy: 0.7925 - val_loss: 1.0867 - learning_rate: 1.0000e-05
# Epoch 16/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9690 - loss: 0.1999
# Epoch 16: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9691 - loss: 0.2000 - val_accuracy: 0.7987 - val_loss: 1.0896 - learning_rate: 5.0000e-06
# Epoch 17/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9558 - loss: 0.2333
# Epoch 17: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9556 - loss: 0.2334 - val_accuracy: 0.7925 - val_loss: 1.1973 - learning_rate: 5.0000e-06

# %%
validation_loss, validation_accuracy = model.evaluate(validation_generator)
print(f"Validation Loss: {validation_loss:.3f}, Validation Accuracy: {validation_accuracy:.2%}")

test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss:.3f}, Test Accuracy: {test_accuracy:.2%}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8232 - loss: 0.9429
# Validation Loss: 1.192, Validation Accuracy: 77.99%
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8412 - loss: 0.7121
# Test Loss: 0.736, Test Accuracy: 83.17%

# %%
predictions = model.predict(test_generator)
class_labels = list(test_generator.class_indices.keys())
true_indices = test_generator.classes
predicted_indices = np.argmax(predictions, axis=1)
prediction_confidences = np.max(predictions, axis=1)

# Visualization function
def visualize_predictions(indices, title, rows=2, cols=5):
    fig, axes = plt.subplots(rows, cols, figsize=(15, 6))
    for i, idx in enumerate(indices):
        img_path = test_generator.filepaths[idx]
        img = plt.imread(img_path)
        true_label = class_labels[true_indices[idx]]
        predicted_label = class_labels[predicted_indices[idx]]
        confidence = prediction_confidences[idx] * 100

        ax = axes[i // cols, i % cols]
        ax.imshow(img)
        ax.axis("off")
        ax.set_title(f"True: {true_label}\nPred: {predicted_label}\nConf: {confidence:.2f}%", fontsize=10)

    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# Lowest and highest confidence predictions
low_conf_indices = np.argsort(prediction_confidences)[:10]
high_conf_indices = np.argsort(prediction_confidences)[-10:][::-1]

visualize_predictions(low_conf_indices, "Lowest 10 Predictions by Confidence")
visualize_predictions(high_conf_indices, "Top 10 Predictions by Confidence")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step

# %%
def evaluate_by_folder(generator, predictions):
    folder_results = defaultdict(lambda: {"correct": 0, "total": 0})
    predicted_indices = np.argmax(predictions, axis=1)

    for filepath, true_idx, pred_idx in zip(generator.filepaths, generator.classes, predicted_indices):
        folder = os.path.basename(os.path.dirname(filepath))
        folder_results[folder]["total"] += 1
        if true_idx == pred_idx:
            folder_results[folder]["correct"] += 1

    return {folder: f"{result['correct']}/{result['total']}" for folder, result in folder_results.items()}

folder_results = evaluate_by_folder(test_generator, predictions)
print("Folder-wise Evaluation Results:")
for folder, result in folder_results.items():
    print(f"{folder}: {result}")
# Out:
# Folder-wise Evaluation Results:
# Aceh_Pintu_Aceh: 6/8
# Bali_Barong: 7/8
# Bali_Merak: 8/8
# DKI_Ondel_Ondel: 7/8
# Jawa_Barat_Megamendung: 6/8
# Jawa_Tengah_Batik_Lasem: 6/8
# Jawa_Timur_Pring: 7/8
# Kalimantan_Barat_Insang: 6/8
# Kalimantan_Dayak: 8/8
# Lampung_Gajah: 6/8
# Madura_Mataketeran: 7/8
# Maluku_Pala: 8/8
# NTB_Lumbung: 8/8
# Palembang_Songket: 8/8
# Papua_Asmat: 4/8
# Papua_Cendrawasih: 6/8
# Papua_Tifa: 7/8
# Solo_Parang: 8/8
# Solo_Sidoluhur: 5/8
# Solo_Sogan: 6/8
# Solo_Truntum: 7/8
# Sulawesi_Selatan_Lontara: 5/8
# Sumatera_Barat_Rumah_Minang: 6/8
# Sumatera_Utara_Boraspati: 8/8
# Yogyakarta_Kawung: 8/8
# Yogyakarta_Sidomukti: 5/8

# %%
output = Output()
upload_widget = FileUpload(accept="image/*", multiple=False)
class_labels = list(test_generator.class_indices.keys())

def handle_upload(change):
    output.clear_output()
    with output:
        # Check if a file is uploaded
        if not upload_widget.value:
            print("Please upload an image file.")
            return
        
        # Access uploaded file content
        try:
            # If upload_widget.value is a dict
            if isinstance(upload_widget.value, dict):
                file = list(upload_widget.value.values())[0]
            # If upload_widget.value is a list or tuple
            elif isinstance(upload_widget.value, (list, tuple)):
                file = upload_widget.value[0]
            else:
                print("Unsupported upload format.")
                return

            temp_path = "./uploaded_image.jpg"
            
            # Save the file to a temporary location
            with open(temp_path, "wb") as f:
                f.write(file["content"])
            
            # Load the model from the checkpoint
            if os.path.exists(CHECKPOINT_PATH):
                print("Loading model from checkpoint...")
                loaded_model = tf.keras.models.load_model(CHECKPOINT_PATH)
            else:
                print("No checkpoint found. Ensure the model is trained and checkpoint exists.")
                return
            
            # Load and preprocess the uploaded image
            img = load_img(temp_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
            img_array = img_to_array(img)
            img_array = np.expand_dims(img_array, axis=0)
            img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)
            
            # Make prediction
            preds = loaded_model.predict(img_array)
            predicted_idx = np.argmax(preds)
            confidence = preds[0][predicted_idx] * 100
            predicted_label = class_labels[predicted_idx]
            
            # Display the uploaded image with prediction result
            plt.figure(figsize=(6, 6))
            img_display = plt.imread(temp_path)
            plt.imshow(img_display)
            plt.axis("off")
            plt.title(f"Prediction: {predicted_label}\nConfidence: {confidence:.2f}%", fontsize=14)
            plt.show()
        
        except Exception as e:
            # Catch and display any errors
            print(f"Error during processing: {str(e)}")

# Observe the upload widget
upload_widget.observe(handle_upload, names="value")
display(upload_widget, output)
# Out:
# FileUpload(value=(), accept='image/*', description='Upload')
# Output()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Initial Train Loss")
plt.plot(history.history["val_loss"], label="Initial Val Loss")
plt.plot(history_fine_tune.history["loss"], label="Fine-tune Train Loss")
plt.plot(history_fine_tune.history["val_loss"], label="Fine-tune Val Loss")
plt.legend()
plt.title("Loss Curve")

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Initial Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Initial Val Accuracy")
plt.plot(history_fine_tune.history["accuracy"], label="Fine-tune Train Accuracy")
plt.plot(history_fine_tune.history["val_accuracy"], label="Fine-tune Val Accuracy")
plt.legend()
plt.title("Accuracy Curve")

plt.show()

# %%
# # Path to the .keras model
# keras_model_path = CHECKPOINT_PATH

# # Path to save the .h5 model
# h5_model_path = os.path.join(MODEL_DIR, "model_checkpoint_best_3_h.h5")

# # Step 1: Load the .keras model
# model = tf.keras.models.load_model(keras_model_path)
# print("Model loaded successfully.")

# # Step 2: Save the model in .h5 format
# model.save(h5_model_path, save_format="h5")
# print(f"Model saved successfully to {h5_model_path}.")

# %%
# # Save the model architecture to JSON
# model_json = model.to_json()
# with open(os.path.join(MODEL_DIR, 'model_architecture.json'), 'w') as json_file:
#     json_file.write(model_json)
# print("Model architecture saved successfully.")
